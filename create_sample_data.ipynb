# %%
from pathlib import Path

# 保存先
base_path = Path("./RAG_test_data")

# ============================================================
# RAG検証用 社内文書
# 各文書を十分長くして、複数チャンクへの分割を確認する
# ============================================================

documents = [

    # ========================================================
    # 人事 / 休暇
    # ========================================================
    (
        "人事/休暇/有給休暇.txt",
        """有給休暇規定

1. 有給休暇の概要

有給休暇は、従業員が心身のリフレッシュや私用などのために取得できる休暇です。
会社は、従業員が適切に休暇を取得できるよう、所定の休暇制度を設けています。
有給休暇の取得にあたっては、業務への影響を考慮し、原則として事前に申請してください。

2. 付与日数

有給休暇は入社後10日付与されます。
その後の付与日数は、勤続年数や会社の規定に応じて決定されます。
付与された有給休暇の残日数については、社内の勤怠システムから確認できます。
付与日数や残日数について疑問がある場合は、人事部または労務担当者へ確認してください。

3. 取得方法

有給休暇を取得する場合は、原則として事前に社内の勤怠システムから申請してください。
申請時には取得予定日と取得日数を登録し、所属長の承認を受ける必要があります。
半日単位などの休暇については、会社が定めた取得方法に従って申請してください。

4. 取得日の変更

申請後に取得日を変更する必要が生じた場合は、勤怠システム上の申請内容を確認し、必要な修正を行ってください。
業務上やむを得ない事情がある場合は、所属長と取得時期について相談してください。
休暇取得後は、実際の取得状況と勤怠システムの登録内容に相違がないことを確認してください。"""
    ),

    (
        "人事/休暇/産休.txt",
        """産前産後休業について

1. 制度の概要

産前産後休業は、出産する従業員が取得できる休業制度です。
出産前後の従業員が安心して休業できるよう、会社では所定の手続きを定めています。
休業を希望する場合は、できるだけ早い段階で所属長および人事部へ相談してください。

2. 産前休業

産前休業を希望する場合は、出産予定日をもとに人事部へ事前に申請してください。
申請時には会社所定の申請書類を提出し、必要に応じて出産予定日を確認できる書類を提出してください。
休業開始日については、申請内容を確認したうえで人事部と調整します。

3. 産後休業

産後休業についても、会社所定の手続きに従って取得する必要があります。
出産日が当初の予定と異なった場合は、休業期間にも変更が生じる可能性があります。
出産後に変更が発生した場合は、速やかに人事部へ連絡してください。

4. 復職

休業期間終了後に復職する場合は、復職予定日について事前に人事部と確認してください。
勤務時間や勤務場所について相談が必要な場合は、復職前に所属長へ相談してください。
制度の利用方法や必要書類について不明な点がある場合は、人事部へ確認してください。"""
    ),

    (
        "人事/休暇/欠勤.txt",
        """欠勤について

1. 欠勤時の連絡

従業員が勤務日に出勤できない場合は、原則として所属長へ事前に連絡してください。
体調不良などにより事前の連絡が難しい場合は、連絡が可能になった時点で速やかに連絡してください。
連絡する際には、欠勤する日や現在の状況について、可能な範囲で伝えてください。

2. 勤怠処理

欠勤した場合は、勤怠システムに必要な情報を登録する必要があります。
欠勤と有給休暇では勤怠上の扱いが異なるため、申請内容を間違えないよう注意してください。
有給休暇を利用できる場合は、有給休暇として申請することもできます。
申請方法について不明な場合は、所属長または労務担当者へ確認してください。

3. 長期欠勤

病気やその他の事情により長期間の欠勤が必要となる場合は、人事部へ相談してください。
長期間の欠勤については、通常の欠勤とは異なる手続きが必要となる場合があります。
会社から必要書類の提出を求められた場合は、指定された期限までに提出してください。

4. 注意事項

欠勤の連絡を行わず勤務を休むことは、会社の勤怠管理上問題となる場合があります。
やむを得ない事情がある場合でも、可能な限り早く所属長へ連絡してください。"""
    ),

    # ========================================================
    # 人事 / 申請
    # ========================================================
    (
        "人事/申請/有給休暇申請書.txt",
        """有給休暇申請について

1. 申請方法

有給休暇を取得する場合は、社内の勤怠システムから有給休暇申請を行ってください。
申請時には、取得する日付と日数を正確に入力してください。
原則として、休暇を取得する前に申請を完了し、所属長の承認を受ける必要があります。

2. 申請内容

申請内容には、休暇を取得する日付、取得日数、休暇区分などを登録します。
入力内容に誤りがある場合は、承認される前に内容を確認し、必要に応じて修正してください。
申請後は、勤怠システムから承認状況を確認できます。

3. 取得日の変更

申請した休暇の日付を変更する場合は、既存の申請内容を確認してください。
会社の勤怠システムで変更が可能な場合は、所定の方法で申請内容を修正してください。
すでに承認されている場合など、システム上で変更できない場合は所属長または労務担当者へ相談してください。

4. 申請に関する問い合わせ

勤怠システムの操作方法が分からない場合は、情報システム部へ問い合わせてください。
有給休暇の付与日数や残日数については、人事部または労務担当者へ確認してください。
申請期限や承認手続きについては、所属部署の運用ルールも確認してください。"""
    ),

    (
        "人事/申請/休職申請書.txt",
        """休職申請について

1. 休職制度

長期間にわたって勤務することが難しく、休職を希望する場合は、会社所定の手続きを行う必要があります。
休職制度を利用する場合は、まず所属長および人事部へ相談してください。
休職理由や希望する期間などを確認したうえで、必要な申請手続きを案内します。

2. 申請書類

休職を希望する従業員は、会社所定の休職申請書を提出してください。
休職理由によっては、理由を確認するための書類を提出する必要があります。
必要書類や提出期限については、人事部からの案内に従ってください。

3. 休職期間

休職の開始日や期間については、申請内容を確認したうえで会社が決定します。
休職期間を延長する必要がある場合は、期間終了前に人事部へ相談してください。
休職期間終了後の復職についても、事前に人事部と確認してください。

4. その他の手続き

休職期間中の給与や社会保険などの取り扱いについては、個別に人事部へ確認してください。
休職中に住所や連絡先などの登録情報が変更になった場合も、会社へ届け出てください。
制度について分からないことがある場合は、自己判断せず人事部へ確認してください。"""
    ),

    # ========================================================
    # 人事 / 評価
    # ========================================================
    (
        "人事/評価/人事評価制度.txt",
        """人事評価制度について

1. 評価制度の目的

人事評価は、従業員の業務実績や勤務状況、担当業務への取り組みなどを総合的に評価する制度です。
評価結果は、従業員の成長や今後の業務目標を検討するために利用されます。
評価を通じて、本人と所属長が業務上の課題や今後の目標を共有することも目的としています。

2. 評価時期

人事評価は原則として年2回実施されます。
評価期間中の業務成果だけではなく、目標に対する達成状況や業務への取り組み姿勢なども確認します。
評価対象となる期間や提出期限については、人事部から別途案内されます。

3. 評価項目

評価では、担当業務における成果、業務品質、周囲との協力、問題解決への取り組みなどを確認します。
管理職については、チームのマネジメントやメンバーの育成なども評価対象となる場合があります。
具体的な評価項目については、職種や役職によって異なる場合があります。

4. 評価結果

評価結果は、上司との面談を通じて本人へ共有されます。
評価結果をもとに、今後の業務目標や育成計画について話し合います。
評価制度について質問がある場合は、人事部へ問い合わせてください。"""
    ),

    (
        "人事/評価/昇格基準.txt",
        """昇格基準について

1. 昇格の考え方

昇格は、従業員の業務実績、能力、勤務状況などを総合的に考慮して決定されます。
現在担当している業務だけではなく、上位の役割を担当するために必要な能力も評価対象となります。
単に勤務年数が長いことだけを理由として昇格が決定されるものではありません。

2. 評価との関係

人事評価の結果は、昇格を検討する際の参考情報として利用されます。
ただし、人事評価の結果だけで昇格が決定されるものではありません。
所属部署からの推薦や会社全体の人員計画、組織上の必要性なども考慮されます。

3. 能力と実績

上位の役割を担うために必要な専門知識や業務遂行能力が身についているかを確認します。
また、担当業務において継続的に成果を上げているか、周囲と協力して業務を進められているかなども考慮されます。

4. 問い合わせ

昇格に関する具体的な基準や現在の評価状況について確認したい場合は、所属長または人事部へ相談してください。
個別の昇格判断については、会社所定の評価手続きに基づいて決定されます。"""
    ),

    # ========================================================
    # 労務 / 勤怠
    # ========================================================
    (
        "労務/勤怠/勤怠規定.txt",
        """勤怠規定

1. 勤怠記録

従業員は、始業時刻までに勤務場所へ到着し、所定の方法で勤怠を記録してください。
出勤、退勤、休憩時間などは正確に登録する必要があります。
勤怠情報は給与計算や勤務状況の確認にも利用されるため、実際の勤務状況と異なる登録を行ってはいけません。

2. 休暇の申請

有給休暇やその他の休暇を取得する場合も、勤怠システムから所定の申請を行ってください。
休暇の種類によって申請方法や必要な承認者が異なる場合があります。
申請した休暇については、承認状況を確認してください。

3. 修正

登録内容に誤りがある場合は、速やかに所属長へ連絡して修正してください。
特に出勤時刻や退勤時刻に誤りがある場合は、給与計算に影響する可能性があります。
修正方法が分からない場合は、労務担当者へ確認してください。

4. 勤怠システム

勤怠システムでは、出退勤の記録だけでなく、有給休暇の残日数や申請状況なども確認できます。
システムにログインできない場合や正常に動作しない場合は、情報システム部へ問い合わせてください。"""
    ),

    (
        "労務/勤怠/遅刻・早退.txt",
        """遅刻・早退について

1. 遅刻時の対応

始業時刻に間に合わない場合は、可能な限り事前に所属長へ連絡してください。
やむを得ず事前に連絡できなかった場合は、出勤後に速やかに事情を説明してください。
遅刻した時間については、勤怠システムへ正確に登録してください。

2. 早退時の対応

勤務時間の途中で帰宅する必要がある場合は、事前に所属長へ相談してください。
早退する場合も、実際の退勤時刻を勤怠システムへ正確に登録してください。
業務上の引き継ぎが必要な場合は、早退前に必要な対応を行ってください。

3. 有給休暇との関係

有給休暇を利用して遅刻や早退の時間を処理する場合は、会社所定の申請方法に従ってください。
有給休暇を利用するか欠勤として処理するかによって勤怠上の扱いが異なる場合があります。
判断に迷う場合は、所属長または労務担当者へ確認してください。

4. その他

繰り返し遅刻や早退が発生する場合は、所属長と勤務状況について相談してください。
勤怠記録に誤りがある場合は、速やかに修正手続きを行ってください。"""
    ),

    (
        "労務/勤怠/テレワーク勤務規定.txt",
        """テレワーク勤務規定

1. テレワーク勤務

テレワーク勤務は、会社が承認した従業員を対象として実施します。
テレワーク勤務を行う場合も、通常の勤務日と同様に始業時と終業時の勤怠を記録してください。
勤務時間中は業務に必要な連絡を受けられる状態を維持してください。

2. 休暇取得

テレワーク勤務日に休暇を取得する場合も、通常の休暇申請手続きに従います。
有給休暇を取得する場合は、勤怠システムから事前に申請してください。
休暇を取得する日にテレワーク勤務を行うことはできないため、勤務予定と休暇申請の内容を確認してください。

3. 勤務環境

テレワークを行う場所は、業務情報を安全に取り扱える環境を選択してください。
第三者が業務資料やPC画面を閲覧できる場所での業務は避けてください。
会社から貸与されたPCや情報資産についても、通常のセキュリティ規定に従って管理してください。

4. 問題発生時

通信環境やPCなどに問題が発生して業務を継続できない場合は、所属長へ連絡してください。
会社貸与PCの故障や紛失などについては、情報システム部へ速やかに報告してください。"""
    ),

    # ========================================================
    # 労務 / 給与
    # ========================================================
    (
        "労務/給与/給与規定.txt",
        """給与規定

1. 給与支給

給与は毎月1回、会社が定めた給与支給日に指定された口座へ振り込まれます。
給与額は基本給、各種手当、控除額などをもとに計算されます。
給与支給日が休日にあたる場合の取り扱いについては、会社が定める給与規定に従います。

2. 控除

健康保険料、厚生年金保険料、雇用保険料などの従業員負担分は給与から控除されます。
所得税などの税金についても、法令に基づいて給与から控除されます。
控除内容については、毎月の給与明細から確認できます。

3. 給与明細

給与明細は社内システムから確認できます。
給与額や控除額に疑問がある場合は、まず給与明細の内容を確認してください。
それでも不明な点がある場合は、労務担当者へ問い合わせてください。

4. 登録情報

住所や振込口座など給与に関係する登録情報を変更する場合は、所定の手続きを行ってください。
変更手続きを行わない場合、給与や税務上の処理に影響する可能性があります。
登録情報に変更があった場合は、速やかに会社へ届け出てください。"""
    ),

    (
        "労務/給与/賞与規定.txt",
        """賞与規定

1. 賞与の基本方針

賞与は、会社の業績や従業員個人の勤務実績などを考慮して支給されます。
賞与の支給は会社の業績などによって変更される場合があります。
支給額や支給時期については、会社が定める賞与規定に従います。

2. 算定

賞与の算定にあたっては、所定の評価期間における勤務状況や業務実績などが考慮されます。
人事評価の結果が賞与額の決定に利用される場合があります。
具体的な算定方法については、職種や役職などによって異なる場合があります。

3. 支給対象

支給対象者や支給条件については、会社が定める賞与規定に従います。
在籍状況や休職などの勤務状況によっては、支給額に影響する場合があります。
詳細な条件については、労務担当者へ確認してください。

4. 問い合わせ

賞与の支給日、算定方法、支給条件などについて質問がある場合は、労務担当者へ問い合わせてください。
個別の支給額については、会社所定の計算方法に基づいて決定されます。"""
    ),

    # ========================================================
    # 労務 / 社会保険
    # ========================================================
    (
        "労務/社会保険/健康保険.txt",
        """健康保険について

1. 健康保険制度

健康保険は、従業員やその家族が病気やけがをした場合などに医療費の負担を軽減するための制度です。
会社と従業員が所定の割合で保険料を負担します。
従業員負担分の保険料は、原則として毎月の給与から控除されます。

2. 加入手続き

入社時には、会社が定める手続きに従って健康保険の加入手続きを行います。
扶養家族に関する変更がある場合は、必要な書類を提出してください。
結婚や出産などによって扶養状況が変わった場合は、速やかに労務担当者へ連絡してください。

3. 退職時

退職などによって健康保険の資格に変更が生じる場合も、会社所定の手続きが必要です。
退職後の健康保険については、加入する制度によって必要な手続きが異なります。
詳細については会社の労務担当者や公的機関へ確認してください。

4. 問い合わせ

健康保険料や加入資格などについて疑問がある場合は、労務担当者へ問い合わせてください。
必要に応じて健康保険組合などの公的機関へ確認する場合があります。"""
    ),

    (
        "労務/社会保険/厚生年金.txt",
        """厚生年金について

1. 厚生年金制度

厚生年金は、会社員などを対象とした公的年金制度です。
会社と従業員が保険料を負担し、従業員負担分は給与から控除されます。
加入期間や保険料などは、将来の年金給付を計算する際の基礎となります。

2. 加入手続き

入社などによって厚生年金の加入資格が発生した場合は、会社が所定の手続きを行います。
従業員から必要な情報や書類の提出を求める場合がありますので、案内に従ってください。
住所変更など、年金に関係する情報に変更がある場合は、速やかに会社へ届け出てください。

3. 退職

退職によって厚生年金の加入資格がなくなる場合は、会社が資格喪失に関する手続きを行います。
退職後の年金制度については、次の勤務先や個人の状況によって必要な手続きが異なります。
詳しい手続きについては、年金事務所などの公的機関へ確認してください。

4. 問い合わせ

厚生年金の加入期間や保険料などについて確認したい場合は、労務担当者へ問い合わせてください。
制度の詳細については、日本年金機構などの公的機関の案内も確認してください。"""
    ),

    # ========================================================
    # 総務
    # ========================================================
    (
        "総務/福利厚生/福利厚生規定.txt",
        """福利厚生規定

1. 福利厚生制度

会社では、従業員が安心して働ける環境を整えるため、複数の福利厚生制度を用意しています。
福利厚生制度には、健康支援、慶弔関連の制度、各種補助制度などがあります。
制度ごとに対象者や利用条件が異なるため、利用前に制度の内容を確認してください。

2. 申請方法

福利厚生制度を利用する場合は、それぞれの制度で定められた申請手続きを行ってください。
申請期限や必要書類などの条件は制度によって異なります。
申請内容に不備がある場合は、担当部署から修正や追加資料の提出を求める場合があります。

3. 制度変更

福利厚生制度の内容は、会社の状況などに応じて変更される場合があります。
制度を利用する際には、最新の社内規定や案内を確認してください。
古い資料に記載された内容が現在の制度と異なる場合があります。

4. 問い合わせ

利用できる制度や申請方法が分からない場合は、総務担当者へ問い合わせてください。
申請期限を過ぎた場合の取り扱いについても、担当者へ確認してください。"""
    ),

    (
        "総務/福利厚生/慶弔見舞金.txt",
        """慶弔見舞金について

1. 制度の概要

従業員本人の結婚、出産、家族の弔事など、会社が定める条件に該当する場合は慶弔見舞金が支給されます。
支給対象となる事由や金額は、会社の規定によって定められています。
事由が発生した場合は、できるだけ早く総務担当者へ相談してください。

2. 申請

慶弔見舞金を申請する場合は、所定の申請書を総務担当者へ提出してください。
申請時には、事由を確認できる書類の提出が必要となる場合があります。
必要書類については、事由の種類によって異なるため、事前に確認してください。

3. 申請期限

慶弔見舞金には申請期限が設定されている場合があります。
申請期限を過ぎると支給を受けられない場合があるため、事由が発生した場合は早めに手続きを行ってください。
申請方法が分からない場合は総務担当者へ確認してください。

4. 支給

支給額や支給方法については、会社が定める規定に従います。
個別の事由が支給対象になるか判断できない場合は、自己判断せず総務担当者へ問い合わせてください。"""
    ),

    (
        "総務/オフィス/オフィス利用規定.txt",
        """オフィス利用規定

1. オフィス利用

オフィスを利用する際は、他の従業員の業務を妨げないようにしてください。
共用スペースを使用した場合は、利用後に整理整頓を行ってください。
会社から貸与された設備や備品は、業務上必要な目的で適切に利用してください。

2. 来訪者

オフィス内へ外部の人を招く場合は、会社所定のルールに従ってください。
来訪者を案内する場合は、必要に応じて担当部署へ事前に連絡してください。
機密情報が保管されている場所へ、許可なく外部の人を案内してはいけません。

3. 設備

オフィス内の設備や備品を利用する場合は、正しい使用方法を確認してください。
設備の故障や破損を発見した場合は、総務担当者へ連絡してください。
私物を共用スペースに長時間放置することは避けてください。

4. 安全管理

安全で快適な職場環境を維持するため、オフィス利用規定を守ってください。
災害や事故などの緊急事態が発生した場合は、会社の緊急時対応手順に従ってください。
避難経路や非常口を塞ぐような物品の設置は禁止されています。"""
    ),

    (
        "総務/オフィス/会議室利用規定.txt",
        """会議室利用規定

1. 会議室の予約

会議室を利用する場合は、社内予約システムから事前に予約してください。
予約時には利用日時、利用者、利用目的などを登録してください。
長時間の利用が必要な場合は、他の利用者への影響を考慮して必要な時間だけ予約してください。

2. 利用方法

利用時間が終了したら、次の利用者が使用できるように机や椅子などを元の状態へ戻してください。
会議中に発生したごみは利用者が処理してください。
会議室に私物や資料を残したまま退室しないよう注意してください。

3. 会議室の設備

会議室に設置されたモニターやプロジェクターなどの機器を利用する場合は、利用方法を確認してから操作してください。
設備に問題がある場合は、無理に修理しようとせず総務担当者へ連絡してください。

4. キャンセル

予約した時間に利用しなくなった場合は、速やかに予約をキャンセルしてください。
予約をキャンセルすることで、他の従業員が会議室を利用できるようになります。
予約方法や設備の利用方法について不明な点がある場合は、総務担当者へ問い合わせてください。"""
    ),

    # ========================================================
    # 情報システム
    # ========================================================
    (
        "情報システム/セキュリティ/情報セキュリティ規定.txt",
        """情報セキュリティ規定

1. 情報資産の管理

会社が保有する情報資産には、顧客情報、従業員情報、業務資料などが含まれます。
従業員は、業務上知り得た情報を適切に管理し、許可なく社外へ持ち出してはいけません。
業務で利用するファイルは、会社が指定した保存場所へ保存してください。

2. メールとファイル

不審なメールやファイルを受け取った場合は、ファイルを開かずに情報システム部へ連絡してください。
送信元が不明なメールや、通常とは異なる内容のメールには注意してください。
業務上必要なファイルを社外へ送信する場合は、会社が定めたルールに従ってください。

3. セキュリティ事故

情報漏えいやセキュリティ上の問題が発生した場合は、速やかに担当部署へ報告してください。
PCの紛失、誤送信、不正アクセスなどもセキュリティ事故として報告が必要となる場合があります。
事故を発見した場合は、自分だけで解決しようとせず、情報システム部へ相談してください。

4. 基本ルール

情報セキュリティに関するルールは、全従業員が遵守する必要があります。
会社の情報を取り扱う際には、常に第三者へ情報が漏れる可能性を考慮してください。
不明な点がある場合は、情報システム部へ確認してください。"""
    ),

    (
        "情報システム/セキュリティ/パスワード管理.txt",
        """パスワード管理について

1. 基本ルール

業務システムで使用するパスワードは、本人以外の人に共有してはいけません。
他のサービスと同じパスワードを使い回すことも避けてください。
パスワードは第三者から推測されにくいものを設定し、安全に管理してください。

2. 保存方法

パスワードを記録する必要がある場合は、会社が認めた方法で安全に管理してください。
付箋や紙など、第三者から簡単に確認できる場所へパスワードを記載することは禁止されています。
業務用のパスワード管理ツールを利用する場合は、会社が承認したツールを使用してください。

3. 不正利用の可能性

不審なログイン通知を受け取った場合や、パスワードが第三者に知られた可能性がある場合は、速やかに情報システム部へ連絡してください。
必要に応じてパスワードの変更やアカウントの停止などの対応を行います。

4. パスワード変更

定期的なパスワード変更が必要なシステムについては、会社が定めたルールに従って変更してください。
パスワード変更後は、新しいパスワードを適切に管理してください。
操作方法やセキュリティに関する質問は情報システム部へ問い合わせてください。"""
    ),

    (
        "情報システム/PC/PC利用規定.txt",
        """PC利用規定

1. 基本的な利用

会社から貸与されたPCは、原則として業務目的で利用してください。
業務に必要な範囲を超えて私的な用途で利用することは避けてください。
PCには会社が指定したセキュリティソフトを導入し、必要な更新を適用してください。

2. 持ち出し

PCを社外へ持ち出す場合は、会社が定めた手続きを確認してください。
外出先や自宅などでPCを利用する場合も、第三者から画面を見られないよう注意してください。
PCを公共の場所に放置することは禁止されています。

3. 離席時

離席する場合は画面をロックし、第三者が業務情報を閲覧できないようにしてください。
短時間の離席であっても、PCをそのままの状態にしないよう注意してください。

4. 紛失・盗難

PCを紛失した場合や盗難にあった場合は、速やかに情報システム部へ連絡してください。
自分で探し続けるのではなく、会社への報告を優先してください。
私的なソフトウェアを無断でインストールすることは禁止されています。"""
    ),

    (
        "情報システム/PC/ソフトウェア利用規定.txt",
        """ソフトウェア利用規定

1. 利用できるソフトウェア

業務で使用するソフトウェアは、会社が許可したものを利用してください。
インターネットから取得したソフトウェアを、許可なく業務用PCへインストールしてはいけません。
無料で提供されているソフトウェアであっても、会社の許可が必要となる場合があります。

2. 有料ソフトウェア

有料ソフトウェアを業務で利用する場合は、事前に会社所定の申請を行ってください。
購入前に必要なライセンス数や利用目的などを確認してください。
個人で購入したライセンスを会社の業務で使用することは避けてください。

3. ライセンス管理

ソフトウェアのライセンスについても適切に管理する必要があります。
退職や異動などによって利用者が変更になった場合は、ライセンスの利用状況を確認してください。
利用していないソフトウェアについても、ライセンス上の問題がないか確認してください。

4. セキュリティ

利用しているソフトウェアにセキュリティ上の問題が発見された場合は、情報システム部の指示に従ってください。
不明なソフトウェアを発見した場合は、自己判断で削除せず担当部署へ確認してください。"""
    ),
]


# ============================================================
# ファイル作成
# ============================================================

for relative_path, content in documents:

    file_path = base_path / relative_path

    # フォルダを作成
    file_path.parent.mkdir(parents=True, exist_ok=True)

    # UTF-8で保存
    file_path.write_text(content, encoding="utf-8")


# ============================================================
# 結果確認
# ============================================================

print(f"{len(documents)}個のテキストファイルを作成しました。")
print(f"保存先: {base_path}")
print()

for path in sorted(base_path.rglob("*.txt")):
    print(path.relative_to(base_path))
# Out:
# 22個のテキストファイルを作成しました。
# 保存先: C:\python\RAG_test_data
#
# 人事\休暇\有給休暇.txt
# 人事\休暇\欠勤.txt
# 人事\休暇\産休.txt
# 人事\申請\休職申請書.txt
# 人事\申請\有給休暇申請書.txt
# 人事\評価\人事評価制度.txt
# 人事\評価\昇格基準.txt
# 労務\勤怠\テレワーク勤務規定.txt
# 労務\勤怠\勤怠規定.txt
# 労務\勤怠\遅刻・早退.txt
# 労務\社会保険\健康保険.txt
# 労務\社会保険\厚生年金.txt
# 労務\給与\給与規定.txt
# 労務\給与\賞与規定.txt
# 情報システム\PC\PC利用規定.txt
# 情報システム\PC\ソフトウェア利用規定.txt
# 情報システム\セキュリティ\パスワード管理.txt
# 情報システム\セキュリティ\情報セキュリティ規定.txt
# 総務\オフィス\オフィス利用規定.txt
# 総務\オフィス\会議室利用規定.txt
# 総務\福利厚生\慶弔見舞金.txt
# 総務\福利厚生\福利厚生規定.txt
